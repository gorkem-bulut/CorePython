# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def urun_bilgileri():
    urun_adi = input("Ürünün adını giriniz: ")
    urun_fiyati = input("Ürünün fiyatını giriniz: ")
    
    with open("urunler.txt", "a") as dosya:
        dosya.write(f"Ürün Adı: {urun_adi}, Fiyat: {urun_fiyati}\n")
    
urun_bilgileri()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[4], line 9
#       6     with open("urunler.txt", "a") as dosya:
#       7         dosya.write(f"Ürün Adı: {urun_adi}, Fiyat: {urun_fiyati}\n")
# ----> 9 urun_bilgileri()
#
# Cell In[4], line 7, in urun_bilgileri()
#       4 urun_fiyati = input("Ürünün fiyatını giriniz: ")
#       6 with open("urunler.txt", "a") as dosya:
# ----> 7     dosya.write(f"Ürün Adı: {urun_adi}, Fiyat: {urun_fiyati}\n")
#
# File c:\Users\Gorkem\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0131' in position 7: character maps to <undefined>

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def degistir():
    eski_kelime = input("Değiştirilmesini istediğiniz kelimeyi giriniz: ")
    yeni_kelime = input("Yeni kelimeyi giriniz: ")
    
    with open("urunler.txt", "r") as dosya:
        icerik = dosya.read()
    yeni_icerik = icerik.replace(eski_kelime, yeni_kelime)
    
    with open("urunler.txt", "w") as dosya:
            dosya.write(yeni_icerik)

degistir()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 13
#      10     with open("urunler.txt", "w") as dosya:
#      11             dosya.write(yeni_icerik)
# ---> 13 degistir()
#
# Cell In[3], line 6, in degistir()
#       3 eski_kelime = input("Değiştirilmesini istediğiniz kelimeyi giriniz: ")
#       4 yeni_kelime = input("Yeni kelimeyi giriniz: ")
# ----> 6 with open("urunler.txt", "r") as dosya:
#       7     icerik = dosya.read()
#       8 yeni_icerik = icerik.replace(eski_kelime, yeni_kelime)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'urunler.txt'

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, name, speed, mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage
    def display_info(self):
        return f"Name: {self.name} Speed: {self.speed} Mileage: {self.mileage}"
        
class Bus(Vehicle):
    def __init__(self, name, speed, mileage):
        Vehicle.__init__(self, name, speed, mileage)

school_bus = Bus("School Volvo", 180, 12)
print(school_bus.display_info())
# Out:
# Name: School Volvo Speed: 180 Mileage: 12
