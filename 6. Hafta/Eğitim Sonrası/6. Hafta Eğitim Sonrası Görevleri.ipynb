# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def cift_mi(sayi):
        if sayi % 2 == 0:
            return sayi
        else:
            raise ValueError("Tek sayı girişi yaptınız!")
        

liste = [434,563,567,22,12,67,50,48,6]  
for sayi in liste:
    try:
       print(cift_mi(sayi))
    except ValueError:
        continue
# Out:
# 434
# 22
# 12
# 50
# 48
# 6

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import random
import time

def game():
    print("0 ile 100 arasında tuttuğum sayıyı bul. Toplam Hak: 5 ve 5 hakkını doldurursan kaybedersin")
    
    rand_num = random.randint(0,101)
    guess_time = 5
    
    while guess_time > 0:
        guess_number = int(input("Tahmininizi giriniz: "))
        time.sleep(1)
        if guess_number > rand_num:
            print("Girmiş olduğunuz sayı tahmin ettiğimden yüksek. Tahmin sayınızı düşürün.")
        elif guess_number < rand_num:
            print("Girmiş olduğunuz sayı tahmin ettiğimden düşük. Tahmin sayınızı yükseltin.")
        else:
            print("Tebrikler!")
        guess_time -= 1
        print(f"Kalan Tahmin Hakkınız: {guess_time}")
        
    if guess_time == 0:
        print(f"Tüm tahmin haklarınızı kullandınız! Tahmin ettiğim sayı: {guess_number}")

game() #run command
# Out:
# 0 ile 100 arasında tuttuğum sayıyı bul. Toplam Hak: 5 ve 5 hakkını doldurursan kaybedersin
# Girmiş olduğunuz sayı tahmin ettiğimden düşük. Tahmin sayınızı yükseltin.
# Kalan Tahmin Hakkınız: 4
# Girmiş olduğunuz sayı tahmin ettiğimden yüksek. Tahmin sayınızı düşürün.
# Kalan Tahmin Hakkınız: 3
# Girmiş olduğunuz sayı tahmin ettiğimden düşük. Tahmin sayınızı yükseltin.
# Kalan Tahmin Hakkınız: 2
# Girmiş olduğunuz sayı tahmin ettiğimden düşük. Tahmin sayınızı yükseltin.
# Kalan Tahmin Hakkınız: 1
# Girmiş olduğunuz sayı tahmin ettiğimden düşük. Tahmin sayınızı yükseltin.
# Kalan Tahmin Hakkınız: 0
# Tüm tahmin haklarınızı kullandınız! Tahmin ettiğim sayı: 47
